# %% [markdown]
# # DASC 41103 - Project 3

# %% [markdown]
# ## Import dependencies

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, Subset, Dataset

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import pathlib
import os
from PIL import Image

# %% [markdown]
# ## Import data

# %%
# Set path to data
logo_path = pathlib.Path('C:/Users/addyw/OneDrive/Documents/dasc41103/proj3/data')

# Read in a list of individual file paths
file_list = sorted([str(path) for path in logo_path.glob('*.png')])

# %%
# View image dataset
fig = plt.figure(figsize=(20, 10))

for i, file in enumerate(file_list):
    img = Image.open(file)

    ax = fig.add_subplot(10, 11, i+1)
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(img)
    ax.set_title(os.path.basename(file), size=5)
    
plt.tight_layout()
plt.show()

# %%
# The images have variable sizes; we need to determine the smallest image dimensions
min_x = 10000
min_y = 10000
min_z = 4

for i, file in enumerate(file_list):
    img = Image.open(file)

    if np.array(img).shape[0] < min_x : min_x = np.array(img).shape[0]
    if np.array(img).shape[1] < min_y : min_y = np.array(img).shape[1]
    if np.array(img).shape[2] < min_z : min_z = np.array(img).shape[2]

print(f"Minimum image dimensions: ({min_x}, {min_y}, {min_z})")
# Out:
# Minimum image dimensions: (708, 648, 4)

# %%
# Set labels (nologo = 0 class)
labels = [0 if 'no' in os.path.basename(file) else 1
          for file in file_list]

# %%
class Joint_UDF_Dataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    # returns the corresponding sample to the given index
    def __getitem__(self, index):
        return self.x[index], self.y[index]

# %%
# Construct UDF dataset
joint_UDF_dataset = Joint_UDF_Dataset(file_list, labels)

for item in joint_UDF_dataset:
    print(' x: ', item[0], ' y: ', item[1])
# Out:
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-01.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-02.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-03.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-04.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-05.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-06.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-07.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-08.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-09.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-10.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-11.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-12.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-13.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-14.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-15.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-16.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-17.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-18.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-19.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-20.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-21.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-22.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-23.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-24.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-25.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-26.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-27.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-28.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-29.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-30.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-31.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-32.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-33.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-34.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-35.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-36.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-37.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-38.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-39.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-40.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-41.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-42.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-43.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-44.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-45.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-46.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-47.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-48.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-49.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-50.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-51.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-52.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-53.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-54.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\logo-55.png  y:  1
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-01.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-02.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-03.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-04.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-05.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-06.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-07.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-08.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-09.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-10.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-11.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-12.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-13.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-14.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-15.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-16.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-17.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-18.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-19.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-20.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-21.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-22.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-23.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-24.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-25.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-26.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-27.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-28.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-29.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-30.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-31.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-32.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-33.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-34.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-35.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-36.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-37.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-38.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-39.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-40.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-41.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-42.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-43.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-44.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-45.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-46.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-47.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-48.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-49.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-50.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-51.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-52.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-53.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-54.png  y:  0
#  x:  C:\Users\addyw\OneDrive\Documents\dasc41103\proj3\data\nologo-55.png  y:  0

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### Resize images

# %%
# Set minimum image dimensions: (708, 648, 4)
img_height, img_width = 708, 648

# Transform images to uniform size
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((img_height, img_width)),
])

class ImageDataset(Dataset):
    def __init__(self, file_list, labels, transform=None):
        self.file_list = file_list
        self.labels = labels
        self.transform = transform
    def __getitem__(self, index):
        img = Image.open(self.file_list[index])
        if self.transform is not None:
            img = self.transform(img)
        label = self.labels[index]
        return img, label
    def __len__(self):
        return len(self.labels)

data = ImageDataset(file_list, labels, transform)

# %%
fig = plt.figure(figsize=(20,10))
for i, example in enumerate(data):
    ax = fig.add_subplot(10, 11, i+1)
    ax.set_xticks([]); ax.set_yticks([])

    # adding to fix warning that some values were outside [0,1] with range [0.000551827..1.0000002]
    # Clamp the tensor values to the range [0, 1] before displaying
    img_display = torch.clamp(example[0], 0, 1)

    # back to original book code
    ax.imshow(img_display.numpy().transpose((1, 2, 0)))
    ax.set_title(f'{example[1]}', size=15)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Split data into training, testing, and validation sets

# %%
# Set seed
torch.manual_seed(41103)

# Define split sizes; 22/110 -> 20% of the dataset
valid_size = 22                 
dataset_size = len(data)

indices = torch.randperm(dataset_size)

test_size = dataset_size // 5
valid_size = dataset_size // 5

test_idx = indices[:test_size]
valid_idx = indices[test_size:test_size+valid_size]
train_idx = indices[test_size+valid_size:]

train_transform = transforms.Compose([
    #transforms.RandomCrop((454, 454)),
    transforms.RandomHorizontalFlip(),
    transforms.Resize((500, 500)),
    transforms.ToTensor(),
])

eval_transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.ToTensor(),
])

dataset = ImageDataset(file_list, labels, transform=train_transform)

train_dataset = Subset(dataset, train_idx)
valid_dataset = Subset(ImageDataset(file_list, labels, transform=eval_transform), valid_idx)
test_dataset  = Subset(ImageDataset(file_list, labels, transform=eval_transform), test_idx)

train_dl = DataLoader(train_dataset, batch_size=8, shuffle=True)
valid_dl = DataLoader(valid_dataset, batch_size=8, shuffle=False)
test_dl  = DataLoader(test_dataset,  batch_size=8, shuffle=False)

# %% [markdown]
# ## Model construction

# %%
# define sequential neural network model
model = nn.Sequential()

model.add_module('conv1', nn.Conv2d(in_channels=4, out_channels=32, kernel_size=5, padding=2))
model.add_module('relu1', nn.ReLU())
model.add_module('pool1', nn.MaxPool2d(kernel_size=2))

model.add_module('conv2', nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2))
model.add_module('relu2', nn.ReLU())
model.add_module('pool2', nn.MaxPool2d(kernel_size=2))

# shrink feature maps to 16x16 regardless of input size
model.add_module('gap', nn.AdaptiveAvgPool2d((16, 16)))

# flatten and feed into FC layers
model.add_module('flatten', nn.Flatten())
model.add_module('fc1', nn.Linear(64 * 16 * 16, 1024))
model.add_module('relu3', nn.ReLU())
model.add_module('dropout', nn.Dropout(p=0.5))
model.add_module('fc2', nn.Linear(1024, 2))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# takes the architecture we previously established and stores it in a model, pulls in 
#  training and test data, and loads any other meaningful parameters

def train(model, num_epochs, train_dl, valid_dl):
    loss_hist_train = [0] * num_epochs
    accuracy_hist_train = [0] * num_epochs
    loss_hist_valid = [0] * num_epochs
    accuracy_hist_valid = [0] * num_epochs
    
    # for each epoch: 
    for epoch in range(num_epochs):
        
        # put the model in training mode
        model.train()
        
        # for each batch:
        for x_batch, y_batch in train_dl:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            
            # forward pass
            pred = model(x_batch)

            # calculate loss
            loss = loss_fn(pred, y_batch)

            # back propagation
            loss.backward()

            # update weights
            optimizer.step()

            # reset the gradients to zero (allows us to run the gradient again)
            optimizer.zero_grad()

            # store outputs (loss, accuracy) of this batch
            loss_hist_train[epoch] += loss.item()*y_batch.size(0)
            is_correct = (torch.argmax(pred, dim=1) == y_batch).float()
            accuracy_hist_train[epoch] += is_correct.sum().cpu()

        loss_hist_train[epoch] /= len(train_dl.dataset)
        accuracy_hist_train[epoch] /= len(train_dl.dataset)

        # put the model in evaluation mode
        model.eval()
        with torch.no_grad():
            # for every validation set- calculate evaluation metrics
            for x_batch, y_batch in valid_dl:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                pred = model(x_batch)
                
                # calculate and store loss
                loss = loss_fn(pred, y_batch)
                loss_hist_valid[epoch] += loss.item()*y_batch.size(0)
                
                # calculate and store accuracy
                is_correct = (torch.argmax(pred, dim=1) == y_batch).float()
                accuracy_hist_valid[epoch] += is_correct.sum().cpu()

        loss_hist_valid[epoch] /= len(valid_dl.dataset)
        accuracy_hist_valid[epoch] /= len(valid_dl.dataset)

        # update user on model progress; allows user to monitor overfitting 
        #  (i.e training vs validation accuracy)
        print(f'Epoch {epoch+1} accuracy: {accuracy_hist_train[epoch]:.4f} val_accuracy: {accuracy_hist_valid[epoch]:.4f}')
    
    # return model and evaluation metrics
    return loss_hist_train, loss_hist_valid, accuracy_hist_train, accuracy_hist_valid

# %%
torch.manual_seed(41103)

num_epochs = 20

hist = train(model, num_epochs, train_dl, valid_dl)
# Out:
# Epoch 1 accuracy: 0.4394 val_accuracy: 0.6818
# Epoch 2 accuracy: 0.4697 val_accuracy: 0.6818
# Epoch 3 accuracy: 0.4697 val_accuracy: 0.6364
# Epoch 4 accuracy: 0.5303 val_accuracy: 0.4545
# Epoch 5 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 6 accuracy: 0.5000 val_accuracy: 0.3182
# Epoch 7 accuracy: 0.5152 val_accuracy: 0.3182
# Epoch 8 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 9 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 10 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 11 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 12 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 13 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 14 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 15 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 16 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 17 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 18 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 19 accuracy: 0.5303 val_accuracy: 0.3182
# Epoch 20 accuracy: 0.5303 val_accuracy: 0.3182

# %%
print(model)
# Out:
# Sequential(
#   (conv1): Conv2d(4, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu2): ReLU()
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (gap): AdaptiveAvgPool2d(output_size=(16, 16))
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=16384, out_features=1024, bias=True)
#   (relu3): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=1024, out_features=2, bias=True)
# )

# %%
#saving the full model (architecture + weights)
torch.save(model, 'Group_29_CNN_FullModel.ph')

# %%
x_arr = np.arange(len(hist[0])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist[0], '-o', label='Train loss')
ax.plot(x_arr, hist[1], '-->', label='Validation loss')
ax.set_xlabel('Epoch', size=15)
ax.set_xticks(np.arange(0,21,2))
ax.set_ylabel('Loss', size=15)
ax.legend(fontsize=15)
ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist[2], '-o', label='Train acc.')
ax.plot(x_arr, hist[3], '-->', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_xticks(np.arange(0,21,2))
ax.set_ylabel('Accuracy', size=15)

#plt.savefig('figures/14_13.png')
plt.show()

# %%
# if you're using gpu, synchronize with cpu
if device.type == 'cuda':
    torch.cuda.synchronize()
model_cpu = model.cpu()

def evaluate(model, test_dl):
    model.eval()
    model = model.to(device)
    correct = 0
    total = 0

    with torch.no_grad():
        for x_batch, y_batch in test_dl:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            pred = model(x_batch)
            predicted_labels = torch.argmax(pred, dim=1)

            correct += (predicted_labels == y_batch).sum().item()
            total += y_batch.size(0)

    accuracy = correct / total
    print(f"Test accuracy: {accuracy * 100:.2f}%")
    return accuracy


# Run evaluation
evaluate(model, test_dl)
# Out:
# Test accuracy: 59.09%
# 0.5909090909090909

# %%
num_images = min(len(test_dataset), 144)  # cap at 144 if dataset is larger
fig = plt.figure(figsize=(12, 12))

for i in range(num_images):
    ax = fig.add_subplot(12, 12, i+1)
    ax.set_xticks([]); ax.set_yticks([])

    # get image and label
    img, label = test_dataset[i]           # returns (x, y)
    if img.ndim == 2:                      # grayscale case
        img = img.unsqueeze(0)             # [1, H, W]

    # adapt to model's expected input channels
    if model.conv1.in_channels == 4 and img.shape[0] == 1:
        img = img.repeat(4, 1, 1)          # [4, H, W]

    img_batch = img.unsqueeze(0).to(device)  # [1, C, H, W]

    with torch.no_grad():
        pred = model(img_batch)
    y_pred = torch.argmax(pred, dim=1)

    # plot image and prediction
    ax.imshow(img[0].cpu(), cmap='gray_r')
    ax.text(0.85, 0.15, f'{y_pred.item()}/{label}',
        size=15, color='blue',
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax.transAxes)

plt.show()
